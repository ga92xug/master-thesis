# %%
import wandb

# %%
entity = "ga92xug"
project = "scaling-laws-eq"
run_ids = ["vk37jyq8", "nl4adi0o", "x5ajaryv"]

# %%
wandb.init(entity=entity, project=project, id=run_ids[0], resume=True)
wandb.config.model.value
