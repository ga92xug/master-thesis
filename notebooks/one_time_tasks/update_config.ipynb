# %%
# %cd ../../../scaling-laws-ecnn
# %load_ext autoreload
# %autoreload 2

import wandb
import os
import re
import training.utils as utils
# Out:
# /home/frischs/dev1/scaling-laws-ecnn

# %%
api = wandb.Api()

filters = {
    "config.model._target_": "networks.eq_nasnet.eq_nasnet.EquivariantNASNet",
    #"config.training.dataset.resolution": 192,
    "state": "finished",
    "tags": "constant_scheduler",

}

runs = api.runs(path=f"ga92xug/SL-Scaling", filters=filters)

for run in runs:
    print("\nCurrent name:", run.name)
    #if run.id != "5d0jx4et":
    #    continue
    #continue
    try:
        utils.give_wandb_name(
            model=None,
            wandb_run=run,
            ignore_name=True,
        )
        print("New name:", run.name)
        run.update()
    except Exception as e:
        print(e)
        print(run.name, "FAILED")
# Out:
# Current name: d1-2-3-3
# WARNING: num_layer_blocks not found in model config. Update config 1-2-3-3.
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: d1-2-3-3
# WARNING: num_layer_blocks not found in model config. Update config 1-2-3-3.
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: d1-2-3-3
# WARNING: num_layer_blocks not found in model config. Update config 1-2-3-3.
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: d1-2-3-3
# WARNING: num_layer_blocks not found in model config. Update config 1-2-3-3.
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: b3_d-1-2-2_w3_r96
# New name: b3_d-1-2-2_w3_r96
#
# Current name: b3_d-1-2-2_w2.5_r96
# New name: b3_d-1-2-2_w2.5_r96
#
# Current name: b3_d-1-2-2_w3_r96
# New name: b3_d-1-2-2_w3_r96
#
# Current name: b4_d-1-3-3-3_w0.8_r192
# New name: b4_d-1-3-3-3_w0.8_r192
#
# Current name: b3_d-1-2-2_w2.5_r96
# New name: b3_d-1-2-2_w2.5_r96
#
# Current name: b4_d-1-3-3-3_w0.6_r192
# New name: b4_d-1-3-3-3_w0.6_r192
#
# Current name: b3_d-1-2-2_w3_r96
# New name: b3_d-1-2-2_w3_r96
#
# Current name: b4_d-1-3-3-3_w0.8_r192
# New name: b4_d-1-3-3-3_w0.8_r192
#
# Current name: b3_d-1-2-2_w2.5_r96
# New name: b3_d-1-2-2_w2.5_r96
#
# Current name: b4_d-1-3-3-3_w0.6_r192
# New name: b4_d-1-3-3-3_w0.6_r192
#
# Current name: b4_d-1-2-3-3_w0.8_r128
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: b3_d-1-2-2_w3_r96
# New name: b3_d-1-2-2_w3_r96
#
# Current name: b4_d-1-3-3-3_w0.8_r192
# New name: b4_d-1-3-3-3_w0.8_r192
#
# Current name: b4_d-1-3-3-3_w0.6_r192
# New name: b4_d-1-3-3-3_w0.6_r192
#
# Current name: b3_d-1-2-2_w2.5_r96
# New name: b3_d-1-2-2_w2.5_r96
#
# Current name: b4_d-1-2-3-3_w0.8_r128
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: b3_d-1-2-2_w3_r96
# New name: b3_d-1-2-2_w3_r96
#
# Current name: b4_d-1-3-3-3_w0.8_r192
# New name: b4_d-1-3-3-3_w0.8_r192
#
# Current name: b4_d-1-3-3-3_w0.6_r192
# New name: b4_d-1-3-3-3_w0.6_r192
#
# Current name: b3_d-1-2-2_w2.5_r96
# New name: b3_d-1-2-2_w2.5_r96
#
# Current name: b4_d-1-2-3-3_w0.8_r128
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: b4_d-1-2-3-3_w0.8_r128
# New name: b4_d-1-2-3-3_w0.8_r128
#
# Current name: b4_d-1-3-3-3_w0.6_r192
# New name: b4_d-1-3-3-3_w0.6_r192
#
# Current name: b4_d-1-3-3-3_w0.8_r192
# New name: b4_d-1-3-3-3_w0.8_r192
#
# Current name: b4_d-1-2-3-3_w0.6_r128
# New name: b4_d-1-2-3-3_w0.6_r128
#
# Current name: b4_d-1-2-3-3_w0.75_r192
# New name: b4_d-1-2-3-3_w0.75_r192
#
# Current name: b4_d-1-2-3-3_w0.6_r128
# New name: b4_d-1-2-3-3_w0.6_r128
#
# Current name: b4_d-1-2-3-3_w0.6_r128
# New name: b4_d-1-2-3-3_w0.6_r128
#
# Current name: b4_d-1-2-3-3_w0.75_r192
# New name: b4_d-1-2-3-3_w0.75_r192
#
# Current name: b4_d-1-2-3-3_w0.6_r128
# New name: b4_d-1-2-3-3_w0.6_r128
#
# Current name: b4_d-1-2-3-3_w0.75_r192
# New name: b4_d-1-2-3-3_w0.75_r192
#
# Current name: b4_d-1-2-3-3_w0.6_r128
# New name: b4_d-1-2-3-3_w0.6_r128
#
# Current name: b4_d-1-2-3-3_w2_r128
# New name: b4_d-1-2-3-3_w2_r128
#
# Current name: b4_d-1-2-3-3_w2_r128
# New name: b4_d-1-2-3-3_w2_r128
#
# Current name: b4_d-1-2-3-3_w1_r128
# New name: b4_d-1-2-3-3_w1_r128
#
# Current name: b4_d-1-2-3-3_w1_r128
# New name: b4_d-1-2-3-3_w1_r128
#
# Current name: b4_d-1-2-3-3_w2_r128
# New name: b4_d-1-2-3-3_w2_r128
#
# Current name: b4_d-1-2-3-3_w1.5_r128
# New name: b4_d-1-2-3-3_w1.5_r128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>     utils.give_wandb_name(
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>         model=None,
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>         wandb_run=run,
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>         ignore_name=True,
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>     )
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     print("New name:", run.name)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     run.update()
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> except Exception as e:
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev1/scaling-laws-ecnn/training/one_time_tasks/update_config.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>     print(e)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/apis/public.py:1903, in Run.update(self)
#    1889 """Persist changes to the run object to the wandb backend."""
#    1890 mutation = gql(
#    1891     """
#    1892 mutation UpsertBucket($id: String!, $description: String, $display_name: String, $notes: String, $tags: [String!], $config: JSONString!, $groupName: String) {
#    (...)
#    1901     % RUN_FRAGMENT
#    1902 )
# -> 1903 _ = self._exec(
#    1904     mutation,
#    1905     id=self.storage_id,
#    1906     tags=self.tags,
#    1907     description=self.description,
#    1908     notes=self.notes,
#    1909     display_name=self.display_name,
#    1910     config=self.json_config,
#    1911     groupName=self.group,
#    1912 )
#    1913 self.summary.update()
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/apis/public.py:1959, in Run._exec(self, query, **kwargs)
#    1957 variables = {"entity": self.entity, "project": self.project, "name": self.id}
#    1958 variables.update(kwargs)
# -> 1959 return self.client.execute(query, variable_values=variables)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:212, in retriable.<locals>.decorator.<locals>.wrapped_fn(*args, **kargs)
#     210 @functools.wraps(fn)
#     211 def wrapped_fn(*args: Any, **kargs: Any) -> Any:
# --> 212     return retrier(*args, **kargs)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/sdk/lib/retry.py:131, in Retry.__call__(self, *args, **kwargs)
#     129 while True:
#     130     try:
# --> 131         result = self._call_fn(*args, **kwargs)
#     132         # Only print resolved attempts once every minute
#     133         if self._num_iter > 2 and now - self._last_print > datetime.timedelta(
#     134             minutes=1
#     135         ):
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/apis/public.py:252, in RetryingClient.execute(self, *args, **kwargs)
#     245 @retry.retriable(
#     246     retry_timedelta=RETRY_TIMEDELTA,
#     247     check_retry_fn=util.no_retry_auth,
#     248     retryable_exceptions=(RetryError, requests.RequestException),
#     249 )
#     250 def execute(self, *args, **kwargs):
#     251     try:
# --> 252         return self._client.execute(*args, **kwargs)
#     253     except requests.exceptions.ReadTimeout:
#     254         if "timeout" not in kwargs:
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:52, in Client.execute(self, document, *args, **kwargs)
#      49 if self.schema:
#      50     self.validate(document)
# ---> 52 result = self._get_result(document, *args, **kwargs)
#      53 if result.errors:
#      54     raise Exception(str(result.errors[0]))
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/vendor/gql-0.2.0/wandb_gql/client.py:60, in Client._get_result(self, document, *args, **kwargs)
#      58 def _get_result(self, document, *args, **kwargs):
#      59     if not self.retries:
# ---> 60         return self.transport.execute(document, *args, **kwargs)
#      62     last_exception = None
#      63     retries_count = 0
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/wandb/sdk/lib/gql_request.py:55, in GraphQLSession.execute(self, document, variable_values, timeout)
#      48 data_key = "json" if self.use_json else "data"
#      49 post_args = {
#      50     "headers": self.headers,
#      51     "cookies": self.cookies,
#      52     "timeout": timeout or self.default_timeout,
#      53     data_key: payload,
#      54 }
# ---> 55 request = self.session.post(self.url, **post_args)
#      56 request.raise_for_status()
#      58 result = request.json()
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/requests/sessions.py:635, in Session.post(self, url, data, json, **kwargs)
#     624 def post(self, url, data=None, json=None, **kwargs):
#     625     r"""Sends a POST request. Returns :class:`Response` object.
#     626
#     627     :param url: URL for the new :class:`Request` object.
#    (...)
#     632     :rtype: requests.Response
#     633     """
# --> 635     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/anaconda3/envs/scaling/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/scaling/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/scaling/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/scaling/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/scaling/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def extract_info_from_log(run):
    file = run.file('output.log')
    file.download(replace=True)

    with open(file.name, "r") as log_file:
        console_logs = log_file.read()
        #print(console_logs)
        
        # Define a regular expression pattern to capture both epoch and learning rate
        pattern = r'Epoch (\d+): reducing learning rate of group \d+ to (\d+\.\d+e[-+]?\d+).'
        
        # Find all matches of the pattern in the content
        matches = re.findall(pattern, console_logs)
        
    os.remove("output.log")

    epochs = [int(epoch) for epoch, _ in matches]
    lrs = [float(lr) for _, lr in matches]

    return epochs, lrs

# %%
api = wandb.Api()

filters = {
    "config.model._target_": "networks.eq_nasnet.eq_nasnet.EquivariantNASNet",
    "config.training.epochs": 120,
    "state": "finished",

}

runs = api.runs(path=f"ga92xug/SL-Scaling", filters=filters)


info = {}
for run in runs:
    info[run.id] = {}
    epochs, lr_rates = extract_info_from_log(run)

    info[run.id]["epochs"] = epochs
    info[run.id]["lr_rates"] = lr_rates
    info[run.id]["valid_acc_weigthed"] = run.history(keys=["valid.acc_weighted"]).values[:, 1]
    info[run.id]["name"] = run.name

    break


#print(info)
# Out:
# {'zufkjx7q': {'epochs': [61, 72, 89, 100, 114], 'lr_rates': [0.0025, 0.00125, 0.000625, 0.0003125, 0.00015625], 'valid_acc_weigthed': array([0.25144726, 0.25835907, 0.28141743, 0.3363409 , 0.37302327,
#        0.38838625, 0.46396407, 0.44244859, 0.46948016, 0.47148222,
#        0.47135776, 0.49936688, 0.48025718, 0.51726335, 0.49636069,
#        0.55418473, 0.55299073, 0.53719038, 0.53558779, 0.58426416,
#        0.57163656, 0.5625999 , 0.59009331, 0.58295643, 0.585886  ,
#        0.60647875, 0.62385386, 0.60244828, 0.6107583 , 0.59696227,
#        0.57886529, 0.66188067, 0.63407654, 0.60920835, 0.59380209,
#        0.63207281, 0.58912492, 0.63095534, 0.6495536 , 0.63422096,
#        0.61655486, 0.67290056, 0.6432513 , 0.64208877, 0.68098086,
#        0.62983841, 0.66274667, 0.65311658, 0.59612203, 0.62288296,
#        0.65532559, 0.62962562, 0.64293617, 0.65821862, 0.65839434,
#        0.63664544, 0.64575922, 0.65441734, 0.6684773 , 0.63780105,
#        0.64255118, 0.68594491, 0.69309413, 0.6718111 , 0.67087197,
#        0.62367934, 0.67017269, 0.66557026, 0.65556365, 0.66270465,
#        0.64027941, 0.65692723, 0.67175782, 0.68683422, 0.66384435,
#        0.68201625, 0.68427539, 0.67613184, 0.67277467, 0.68438959,
#        0.6625908 , 0.67435151, 0.66756308, 0.66091895, 0.66327465,
#        0.66360337, 0.70515728, 0.69229466, 0.68644834, 0.67885947,
#        0.69393259, 0.68988901, 0.68852711, 0.68886423, 0.67847776,
#        0.66948342, 0.65769386, 0.66068411, 0.67614752, 0.66495872,
#        0.68753219, 0.69421113, 0.69057304, 0.69114327, 0.69347823,
#        0.69610608, 0.67822635, 0.6887722 , 0.68487668, 0.67265797,
#        0.67246532, 0.68727565, 0.67400318, 0.67372441, 0.6847297 ,
#        0.67935503, 0.68664348, 0.68086523, 0.6840651 , 0.67321599]), 'name': 'b4_d1.4_w1.5_r128'}}
