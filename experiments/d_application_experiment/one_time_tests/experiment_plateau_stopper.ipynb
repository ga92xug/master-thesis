# %%
# Always start at base directory for imports
# %cd
# %cd dev1/scaling-laws-ecnn/
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.set_option('display.max_columns', None)
import torch
from typing import List


import sys
import os
from plotting.experiments.b_NAS.plot_nas_results import scalar_mappable
from experiments.b_NAS.common_best_architecture.util import *
from experiments.b_NAS.util import *
from experiments.run_command import run_command
# Out:
# /home/frischs
# /home/frischs/dev1/scaling-laws-ecnn
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> import sys
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> import os
# ---> <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> from plotting.experiments.b_NAS.plot_nas_results import scalar_mappable
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> from experiments.b_NAS.common_best_architecture.util import *
#      <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> from experiments.b_NAS.util import *
#
# File ~/dev1/scaling-laws-ecnn/plotting/experiments/b_NAS/plot_nas_results.py:14
#      12 sys.path.append(f"{os.getcwd()}")
#      13 from experiments.b_NAS.util import get_name_performance_metric
# ---> 14 from plot.util import get_fig_size
#      16 # textwidth latex 5.78853in
#      17 # textwidth in cm: \printinunitsof{in}\prntlen{\textwidth}
#      19 METADATA = {
#      20         "mnist_rot": {
#      21             "name": "MNIST-rot",
#    (...)
#      42         },
#      43     }
#
# ModuleNotFoundError: No module named 'plot'

# %%
from plotting.experiments.b_NAS.plot_nas_results import scalar_mappable


scalar_mappable
def test():
    # test plateau stopper

    valid_accs =[0.762499988079071, 0.759999990463257, 0.730000019073486, 0.75, 0.774999976158142, 0.75, 0.774999976158142, 0.740000009536743, 0.725000023841858, 0.759999990463257, 0.774999976158142, 0.774999976158142, 0.774999976158142, 0.774999976158142, 0.762499988079071, 0.774999976158142, 0.774999976158142, 0.774999976158142, 0.774999976158142, 0.764999985694885, 0.759999990463257, 0.774999976158142, 0.759999990463257, 0.774999976158142, 0.774999976158142, 0.767499983310699, 0.774999976158142, 0.75, 0.757499992847443, 0.757499992847443, 0.759999990463257, 0.752499997615814, 0.752499997615814, 0.747500002384186, 0.754999995231628, 0.757499992847443, 0.737500011920929, 0.754999995231628, 0.762499988079071, 0.759999990463257, 0.732500016689301, 0.769999980926514, 0.685000002384186, 0.707499980926514, 0.742500007152557, 0.670000016689301, 0.702499985694885, 0.742500007152557, 0.675000011920929, 0.714999973773956, 0.725000023841858, 0.567499995231628]
    # reverse order the list
    valid_accs = valid_accs[::-1]

    print(valid_accs)

    stopper = ExperimentPlateauStopper(
        metric="valid_acc", 
        std=0.001, 
        top=10, 
        mode="max", 
        patience=3, 
        min_trials=5
    )

    for i, acc in enumerate(valid_accs):
        print(f"Epoch {i} - acc: {acc}")
        stop = stopper(None, {"valid_acc": acc})
        print(f"Stop: {stop}")
        if stop:
            break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from plotting.experiments.b_NAS.plot_nas_results import scalar_mappable
#       <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> scalar_mappable
#       <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> def test():
#       <a href='vscode-notebook-cell://ssh-remote%2B100.112.45.127/home/frischs/dev2/scaling-laws-ecnn/experiments/d_application_experiment/one_time_tests/experiment_plateau_stopper.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     # test plateau stopper
#
# File ~/dev1/scaling-laws-ecnn/plotting/experiments/b_NAS/plot_nas_results.py:14
#      12 sys.path.append(f"{os.getcwd()}")
#      13 from experiments.b_NAS.util import get_name_performance_metric
# ---> 14 from plot.util import get_fig_size
#      16 # textwidth latex 5.78853in
#      17 # textwidth in cm: \printinunitsof{in}\prntlen{\textwidth}
#      19 METADATA = {
#      20         "mnist_rot": {
#      21             "name": "MNIST-rot",
#    (...)
#      42         },
#      43     }
#
# ModuleNotFoundError: No module named 'plot'

# %%
scalar_mappable()
