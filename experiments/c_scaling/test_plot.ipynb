# %%
# %cd
# %cd dev1/scaling-laws-ecnn
import matplotlib.pyplot as plt
import numpy as np
from experiments.c_scaling import plot
# reload
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/frischs
# /home/frischs/dev1/scaling-laws-ecnn

# %%
num_points = 5

# Generate a list of FLOPs values.
flops = [np.linspace(1, 8, num_points)] * 4
# Generate a list of accuracy values for each FLOPs value.
accuracy = [plot.generate_fake_log_increasing_acc(50 + 4-i, 2, num_points) for i in range(4)]

plot.plot_scaling_compound_baseline(flops, accuracy, legend_labels=['d=22, r=144', 'd=22, r=96', 'd=16, r=144', 'd=16, r=96'])

# %%
num_points = 5

# Generate a list of FLOPs values.
flops = [np.linspace(1, 8, num_points)] * 3
# Generate a list of accuracy values for each FLOPs value.
accuracy = [plot.generate_fake_log_increasing_acc(50 + np.random.normal(0,1), 2, num_points) for _ in range(3)]

point_labels = [
    [f"w={i}" for i in range(num_points)],
    [f"d={i}" for i in range(num_points)],
    [f"r={i}" for i in range(num_points)],
]

# Create all three subplots.
plot.plot_scaling_individual(flops, accuracy, 'GFLOPs', 'ISIC 2019 Valid Acc(%)', point_labels=point_labels)

# Show the plot.
plt.show()
