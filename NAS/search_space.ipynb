# %%
from ax import (
    ChoiceParameter,
    ParameterType,
    RangeParameter,
    SearchSpace,
    ParameterConstraint,
)
from ax import ParameterType, RangeParameter, SearchSpace
from ax.core import ParameterConstraint, OrderConstraint

# %%
# initial group
initial_group = RangeParameter(
    name=f"0_group",
    lower=0,
    upper=5,
    parameter_type=ParameterType.INT,
    log_scale=False,
)

group = RangeParameter(
    name=f"1_group",
    lower=0,
    upper=5,
    parameter_type=ParameterType.INT,
    log_scale=False,
)


test = OrderConstraint(
            upper_parameter = initial_group,
            lower_parameter = group,
)
