# %%
# %pwd
# %cd ../..
# Out:
# /home/frischs/dev1/scaling-laws-ecnn

# %%
import pandas as pd

# %%
df = pd.read_csv('NAS/data/common_best_architecture/mixed_strategies.csv', index_col=0)
df
# Out:
#                                   gflops  valid_acc   -1_expand_ratio  \
# mnist_rot                      10.313189   0.996727  5.81000491173549
# cifar10                        36.297857   0.910632                 6
# galaxy10                      376.244229   0.822226                 4
# Strategy_mixed_1_0                   NaN        NaN             [4,6]
# Strategy_inspired_galaxy_1_0         NaN        NaN                 4
#
#                               -1_dropout_rate  0_reflection   0_group  \
# mnist_rot                                   0     -0.842003  3.920021
# cifar10                                     0      0.000000  4.000000
# galaxy10                                    0      0.000000  4.000000
# Strategy_mixed_1_0                          0      0.000000  4.000000
# Strategy_inspired_galaxy_1_0                0      0.000000  4.000000
#
#                                    0_out_channels  0_kernel_size  0_stride  \
# ...

# %%
df.loc["Strategy_mixed_1_0"]
# Out:
# gflops                                          NaN
# valid_acc                                       NaN
# -1_expand_ratio                               [4,6]
# -1_dropout_rate                                   0
# 0_reflection                                    0.0
# 0_group                                         4.0
# 0_out_channels                  [1.5,1.75,2.0,2.25]
# 0_kernel_size                                     5
# 0_stride                                          2
# 1_reflection                                    0.0
# 1_group                                     [2,3,4]
# 1_num_layers                    [1.0,1.25,1.5,1.75]
# 1_conv_op                       [conv,dconv,mbconv]
# 1_kernel_size                                   3.0
# 1_se_ratio                      [0.0,0.25,0.5,0.75]
# 1_out_channels     [1.0,1.25,1.5,1.75,2.0,2.25,2.5]
# 1_skip_op                                      conv
# 1_stride                                        1.0
# ...
